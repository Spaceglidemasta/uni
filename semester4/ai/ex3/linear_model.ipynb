# %% [markdown]
# # Exercise 2
# Is there a relationship between advertising budget and sales?

# %% [markdown]
# Yes, there is. Increasing the advertising for TV and Radio media increases the Sales noticeablely,
# altough Newspaper Ads show to have little to no effect on the sales.

# %% [markdown]
# How strong is this relationship between advertising budget and sales? 3 Which media contri-
# bute to sales? Separate individual contributions

# %% [markdown]
# Fitting testing data from the given Dataframe into a linear model yields these results:
#
# sales ~= 2.9051 + 0.0467 * TV + 0.1856 * RADIO + -0.0001 * NEWSPAPER
#
# -> This means that TV and RADIO have a noticeable contribution to the sales, with RADIO having ~ 4x the influence of TV.
# Newspaper on the other hand has no significant correlation to the sales, proven py the p-value of Sales ~ Newspaper beeing 0.984.

# %% [markdown]
# How accurately can we estimate the effect of each medium on sales?

# %% [markdown]
# With high precision: with a conf.int. of [0.044;0.050] and [0.167;0.204] for TV and Radio respectivly, we can, given the already
# addressed coefficients, confidently say that we can estimate the effect of each medium on the sales very accuratly.
#
# For newspaper however, this changes with the conf.int. beeing [-0.012;0.012] and the coef. beeing -0.0001, the aproximated
# correlation inside the linear regression lacks precision by 2 orders of magnitude, making the already incofident relation between
# sales and newspapers obsolete in practice.
#
# ChatGPT korrektur:
# The effects of TV and radio are estimated with high precision, as shown by their narrow confidence intervals: [0.044; 0.050] and [0.167; 0.204], respectively. This indicates that the estimated coefficients are stable and the true effects are likely close to these values.
#
# In contrast, the effect of newspaper advertising is estimated with very low precision, as its confidence interval [-0.012; 0.012] includes zero and is relatively wide compared to its coefficient (-0.0001). Therefore, no statistically reliable effect of newspaper advertising on sales can be concluded from this model.

# %% [markdown]
# How accurately can we predict future sales?

# %% [markdown]
# The polynomal regression of fourth degree shows a Training R² of 0.631 and a Prediction R² of 0.557, showing a small but noticable
# Overfitting of the model.
#
# The polynomal regression of tenth degree however shows negative R², which differ immenseley:
# Training R²     = -0.203
# Prediction R²   = -0.963
# This indicates that is to be expected of the model to falsely predict future sales.
